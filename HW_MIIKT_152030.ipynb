# %% [markdown]
# ### Домашна работа по предметот Методологија на истражувањето во икт

# %% [markdown]
# #### Индекс: 152030

# %% [markdown]
# <p>

# %%
from IPython.display import Image

Image("C:\\Users\\VEECO-PC\\Desktop\\MIIKT Projek\\Barbara1.png")

# %%
import cv2
import numpy as  np
import matplotlib as plt
from IPython.display import Image

Image("C:\\Users\\VEECO-PC\\Desktop\\MIIKT Projek\\Barbara1.png")

img = cv2.imread("Barbara1.jpg", cv2.IMREAD_GRAYSCALE)

f = np.fft.fft2(img)

magnitude_spectrum = 20*np.log(np.aba(f))
magnitude_spectrum = np.asarray(magnitude_spectrum, dtype=np.uint8)

plt.imshow(magnitude_spectrum)

plt.imshow(img,img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5971764684cf> in <module>
#       1 import cv2
#       2 import numpy as  np
# ----> 3 import matplotlib as plt
#       4 from IPython.display import Image
#       5
#
# ModuleNotFoundError: No module named 'matplotlib'
